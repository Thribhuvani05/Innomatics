# %%
#A company evaluates employee performance scores at the end of the year. You are given a dictionary containing employee names and their performance scores.

employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}

# Step 1: Find highest score
max_score = max(employees.values())

# Step 2: Find employees with highest score
top_performers = []

for name, score in employees.items():
    if score == max_score:
        top_performers.append(name)

# Step 3: Print result
print("Top Performers Eligible for Bonus:", ", ".join(top_performers), f"(Score: {max_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %%
import string
text = input("Enter search query: ")

# Step 2: Convert to lowercase
text = text.lower()

# Step 3: Remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))

# Step 4: Split into words
words = text.split()

# Step 5: Count frequency
freq = {}

for word in words:
    freq[word] = freq.get(word, 0) + 1

# Step 6: Keep only words searched more than once
result = {}

for word, count in freq.items():
    if count > 1:
        result[word] = count

# Step 7: Display output
print(result)
# Out:
# Enter search query: Buy mobile phone buy phone online
# {'buy': 2, 'phone': 2}

# %%
sensor_readings = list(map(int, input("Enter sensor readings separated by space: ").split()))

# Step 2: Store valid readings (even numbers) with index
valid_readings = []

for i, value in enumerate(sensor_readings):
    if value % 2 == 0:   # check even
        valid_readings.append((i, value))

# Step 3: Display result
print("Valid Sensor Readings (Hour, Value):")
print(valid_readings)
# Out:
# Enter sensor readings separated by space: 3 5 7
# Valid Sensor Readings (Hour, Value):
# []

# %%
# A company wants to analyze which email providers its users are using. You are given a list of employee email IDs.
n = int(input("Enter number of email IDs: "))

emails = []

# Step 2: Take email inputs
for _ in range(n):
    emails.append(input("Enter email: ").strip())

# Step 3: Count domain frequencies
domain_count = {}

for email in emails:
    domain = email.split("@")[1]   # extract domain
    domain_count[domain] = domain_count.get(domain, 0) + 1

# Step 4: Calculate percentages
total = len(emails)

for domain, count in domain_count.items():
    percentage = (count / total) * 100
    print(f"{domain}: {percentage:.0f}%")

# %%
#A retail company tracks daily sales. Sudden spikes in sales may indicate promotions or unusual activity.
sales = list(map(int, input("Enter daily sales separated by space: ").split()))

# Step 2: Calculate average sales
avg_sales = sum(sales) / len(sales)

# Step 3: Calculate spike threshold (30% above average)
threshold = avg_sales * 1.30

# Step 4: Detect spike days
for i, value in enumerate(sales):
    if value > threshold:
        print(f"Day {i+1}: {value}")

# %%
# A system stores user IDs during registration. Duplicate IDs can cause data integrity issues.
user_ids = input("Enter user IDs separated by space: ").split()

# Step 2: Count frequencies
freq = {}

for uid in user_ids:
    freq[uid] = freq.get(uid, 0) + 1

# Step 3: Display duplicates
for uid, count in freq.items():
    if count > 1:
        print(f"{uid} → {count} times")
